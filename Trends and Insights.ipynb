# %% [markdown]
# # Trends and Insights

# %% [markdown]
# ## 1. Data analysis demonstrated that
# - Mexico was the most frequent origin country, and
# - Australia was the most frequent destination country in the dataset.

# %%
df1['Origin Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Origin Country'>

# %%
df1['Destination Country'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Destination Country'>

# %% [markdown]
# ## 2. Data analysis indicated that
# - 418 instances, there was no delay in delivery
# - 94 instances, deliveries arrived earlier than scheduled
# - and 17 instances, deliveries were delayed.

# %%
print(f'No Delay: {len(df1.loc[df1["Delay"] == 0])}')
print(f'Arrived early: {len(df1.loc[df1["Delay"] > 0])}')
print(f'Delayed: {len(df1.loc[df1["Delay"] < 0])}')
# Out:
# No Delay: 418
# Arrived early: 94
# Delayed: 17

# %% [markdown]
# ## 3. There was no recorded delay due to Anchorage Stay, Cyclone or Non-Optimal Route

# %%
print(f'Delayed due to Anchorage Stay: {len(df1.loc[df1["Delay - Anchorage Stay"] < 0])}')
print(f'Delayed due to Cyclone: {len(df1.loc[df1["Delay - Cyclone"] < 0])}')
print(f'Delayed due to Non-Optimal Route: {len(df1.loc[df1["Delay - Non-Optimal Route"] < 0])}')
# Out:
# Delayed due to Anchorage Stay: 0
# Delayed due to Cyclone: 0
# Delayed due to Non-Optimal Route: 0
